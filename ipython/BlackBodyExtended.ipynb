# %% [markdown]
# # Extended Black Body Radiation Color Map

# %% [markdown]
# This iPython notebook contains the script required to derive a nice color map based on the colors of black body radiation with some blue and purple hues thrown in at the lower end to add some "color." The color map is similar to the default colors used in gnuplot. Colors of the desired brightness and hue are chosen, and then the colors are adjusted such that the luminance is perceptually linear (according to the CIELAB color space).

# %% [markdown]
# This code relies on the [python-colormath](http://python-colormath.readthedocs.org/en/latest/index.html) module. See [its documentation](http://python-colormath.readthedocs.org/en/latest/index.html) for information such as installation instructions. (It can be installed with either pip or macports.)

# %%
from colormath.color_objects import *
from colormath.color_conversions import convert_color

# %% [markdown]
# Mostly because it's habit, I am also using [pandas](http://pandas.pydata.org/) dataframes to organize the data. (Pandas can be installed with macports.)

# %%
import pandas
import numpy

# %% [markdown]
# We will also be using [toyplot](https://toyplot.readthedocs.org) for making visuals. See its documentation for installation instructions.

# %%
import toyplot
import toyplot.pdf

# %% [markdown]
# The black body radiation color map goes from black to red to orange to yellow to white. Create color objects for these 5 control points.

# %%
color_rgb = [(0,0,0), (0,24,168), (99,0,228), (220,20,60), (255,117,56), (238,210,20), (255, 255, 255)]
data = pandas.DataFrame({'RGB': color_rgb})
data
# Out:
#                RGB
# 0        (0, 0, 0)
# 1     (0, 24, 168)
# 2     (99, 0, 228)
# 3    (220, 20, 60)
# 4   (255, 117, 56)
# 5   (238, 210, 20)
# 6  (255, 255, 255)

# %%
data['rgb_values'] = data['RGB'].apply(lambda rgb: sRGBColor(rgb[0], rgb[1], rgb[2],
                                                             is_upscaled=True))

# %% [markdown]
# Convert the rgb values to LAB values and get the luminance out of each of them to define the scalar (on a scale from 0 to 1) of each color.

# %%
data['lab_values'] = data['rgb_values'].apply(lambda rgb: convert_color(rgb, LabColor))
data['scalar'] = data['lab_values'].apply(lambda lab: lab.lab_l/100.0)
data
# Out:
#                RGB                                         rgb_values  \
# 0        (0, 0, 0)  sRGBColor (rgb_r:0.0000 rgb_g:0.0000 rgb_b:0.0...
# 1     (0, 24, 168)  sRGBColor (rgb_r:0.0000 rgb_g:0.0941 rgb_b:0.6...
# 2     (99, 0, 228)  sRGBColor (rgb_r:0.3882 rgb_g:0.0000 rgb_b:0.8...
# 3    (220, 20, 60)  sRGBColor (rgb_r:0.8627 rgb_g:0.0784 rgb_b:0.2...
# 4   (255, 117, 56)  sRGBColor (rgb_r:1.0000 rgb_g:0.4588 rgb_b:0.2...
# 5   (238, 210, 20)  sRGBColor (rgb_r:0.9333 rgb_g:0.8235 rgb_b:0.0...
# 6  (255, 255, 255)  sRGBColor (rgb_r:1.0000 rgb_g:1.0000 rgb_b:1.0...
#
#                                           lab_values    scalar
# 0  LabColor (lab_l:0.0000 lab_a:0.0000 lab_b:0.0000)  0.000000
# 1  LabColor (lab_l:21.8713 lab_a:50.1967 lab_b:-7...  0.218713
# 2  LabColor (lab_l:34.5057 lab_a:75.4071 lab_b:-8...  0.345057
# 3  LabColor (lab_l:47.0349 lab_a:70.9194 lab_b:33...  0.470349
# 4  LabColor (lab_l:65.1786 lab_a:49.1390 lab_b:56...  0.651786
# 5  LabColor (lab_l:84.1336 lab_a:-6.4583 lab_b:82...  0.841336
# 6  LabColor (lab_l:100.0000 lab_a:-0.0005 lab_b:-...  1.000000

# %% [markdown]
# Make a summary table of just the control points.

# %%
colors_short = pandas.DataFrame(data, columns=['scalar', 'RGB'])
colors_short
# Out:
#      scalar              RGB
# 0  0.000000        (0, 0, 0)
# 1  0.218713     (0, 24, 168)
# 2  0.345057     (99, 0, 228)
# 3  0.470349    (220, 20, 60)
# 4  0.651786   (255, 117, 56)
# 5  0.841336   (238, 210, 20)
# 6  1.000000  (255, 255, 255)

# %% [markdown]
# Make a function that will take a scalar value (in the range of 0 and 1) and return the appropriate RGB triple.

# %%
def color_lookup_upscaled(x):
    if x < 0:
        return (0, 0, 0)
    for index in xrange(0, data.index.size-1):
        low_scalar = data['scalar'][index]
        high_scalar = data['scalar'][index+1]
        if (x > high_scalar):
            continue
        low_lab = data['lab_values'][index]
        high_lab = data['lab_values'][index+1]
        interp = (x-low_scalar)/(high_scalar-low_scalar)
        mid_lab = LabColor(interp*(high_lab.lab_l-low_lab.lab_l) + low_lab.lab_l,
                           interp*(high_lab.lab_a-low_lab.lab_a) + low_lab.lab_a,
                           interp*(high_lab.lab_b-low_lab.lab_b) + low_lab.lab_b)
        return convert_color(mid_lab, sRGBColor).get_upscaled_value_tuple()
    return (255, 255, 255)

def color_lookup(x):
    if x < 0:
        return (0.0, 0.0, 0.0)
    for index in xrange(0, data.index.size-1):
        low_scalar = data['scalar'][index]
        high_scalar = data['scalar'][index+1]
        if (x > high_scalar):
            continue
        low_lab = data['lab_values'][index]
        high_lab = data['lab_values'][index+1]
        interp = (x-low_scalar)/(high_scalar-low_scalar)
        mid_lab = LabColor(interp*(high_lab.lab_l-low_lab.lab_l) + low_lab.lab_l,
                           interp*(high_lab.lab_a-low_lab.lab_a) + low_lab.lab_a,
                           interp*(high_lab.lab_b-low_lab.lab_b) + low_lab.lab_b)
        return convert_color(mid_lab, sRGBColor).get_value_tuple()
    return (1.0, 1.0, 1.0)

# %% [markdown]
# Make a long table of colors. This is a very high resolution table of colors that can be easily trimmed down with regular sampling.

# %%
colors_long = pandas.DataFrame({'scalar': numpy.linspace(0.0, 1.0, num=1024)})
colors_long['RGB'] = colors_long['scalar'].apply(color_lookup_upscaled)
colors_long['sRGB'] = colors_long['scalar'].apply(color_lookup)

# %%
def unzip_rgb_triple(dataframe, column='RGB'):
    '''Given a dataframe and the name of a column holding an RGB triplet,
    this function creates new separate columns for the R, G, and B values
    with the same name as the original with '_r', '_g', and '_b' appended.'''
    # Creates a data frame with separate columns for the triples in the given column
    unzipped_rgb = pandas.DataFrame(dataframe[column].values.tolist(),
                                    columns=['r', 'g', 'b'])
    # Add the columns to the original data frame
    dataframe[column + '_r'] = unzipped_rgb['r']
    dataframe[column + '_g'] = unzipped_rgb['g']
    dataframe[column + '_b'] = unzipped_rgb['b']

unzip_rgb_triple(colors_short, 'RGB')
unzip_rgb_triple(colors_long, 'RGB')
unzip_rgb_triple(colors_long, 'sRGB')

# %% [markdown]
# Check to make sure that all the colors are actually valid. The answer to this sum should be 0 if all the values are valid.

# %%
invalid = ((colors_long['sRGB_r'] < 0) | (colors_long['sRGB_r'] > 1) |
           (colors_long['sRGB_g'] < 0) | (colors_long['sRGB_g'] > 1) |
           (colors_long['sRGB_b'] < 0) | (colors_long['sRGB_b'] > 1))
num_bad_values = invalid.sum()
if num_bad_values > 0:
    raise ValueError, 'Found %d invalid colors!!!!' % num_bad_values

# %%
colors_palette = toyplot.color.Palette(colors=colors_long['sRGB'].values)
colors_map = toyplot.color.LinearMap(palette=colors_palette)
#colors_map

# %%
canvas = toyplot.Canvas(width=512, height=200)
axes = canvas.axes()
axes.scatterplot(colors_short['scalar'], numpy.zeros(colors_short['scalar'].shape),
                 marker='|', size=1000,
                 color='gray')
axes.scatterplot(colors_long['scalar'], numpy.zeros(colors_long['scalar'].shape),
                 marker='|', size=500,
                 color=colors_map)
axes.y.show = False
axes.x.show = False

for index in xrange(0, len(colors_short.index), 2):
    axes.text(colors_short['scalar'][index], 0,
              '%1.2f' % colors_short['scalar'][index],
              style={'baseline-shift':'-23px',
                     'font-size': '8pt'},
              color='black')
    axes.text(colors_short['scalar'][index], 0,
              str(colors_short['RGB'][index]),
              style={'baseline-shift':'-34px',
                     'font-size':'7pt'},
              color='black')

for index in xrange(1, len(colors_short.index), 2):
    axes.text(colors_short['scalar'][index], 0,
              '%1.2f' % colors_short['scalar'][index],
              style={'baseline-shift':'34px',
                     'font-size':'8pt'},
              color='black')
    axes.text(colors_short['scalar'][index], 0,
              str(colors_short['RGB'][index]),
              style={'baseline-shift':'23px',
                     'font-size':'7pt'},
              color='black')
# Out:
# <div align="center" class="toyplot" id="te0ed8a5ea1544a6aad7932e864118f4b"><svg height="200.0px" id="tba74734921ea4ebd8fa2abfc86c94d43" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 512.0 200.0" width="512.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="tcf804f1e405748a9b65791690025f9f6"><clipPath id="t35f3cc210b044f48b98964f8f67dfea1"><rect height="120.0" width="432.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t35f3cc210b044f48b98964f8f67dfea1)" style="cursor:crosshair"><rect height="120.0" style="pointer-events:all;visibility:hidden" width="432.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Scatterplot" id="t69d16905b0794fe0878dbcb40b4cece0" style="stroke:none"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 83.02290477921342, 100.0)" x1="83.02290477921342" x2="83.02290477921342" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 153.87256655552616, 100.0)" x1="153.87256655552616" x2="153.87256655552616" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 194.80027849163076, 100.0)" x1="194.80027849163076" x2="194.80027849163076" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 235.38737285201881, 100.0)" x1="235.38737285201881" x2="235.38737285201881" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 294.16181904530316, 100.0)" x1="294.16181904530316" x2="294.16181904530316" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 355.5644587328772, 100.0)" x1="355.5644587328772" x2="355.5644587328772" y1="84.188611699158102" y2="115.8113883008419"></line></g><g class="toyplot-Datum" style="fill:rgb(50.2%,50.2%,50.2%);fill-opacity:1.0;opacity:1.0;stroke:rgb(50.2%,50.2%,50.2%);stroke-opacity:1.0"><line transform="rotate(0, 406.96182536797761, 100.0)" x1="406.96182536797761" x2="406.96182536797761" y1="84.188611699158102" y2="115.8113883008419"></line></g></g></g><g class="toyplot-mark-Scatterplot" id="td62fe161ac114c4395b5c838c76cc656" style="stroke:none"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><line transform="rotate(0, 83.02290477921342, 100.0)" x1="83.02290477921342" x2="83.02290477921342" y1="88.819660112501055" y2="111.18033988749895"></line></g><g class="toyplot-Datum" style="fill:rgb(0.253%,0.0772%,0.466%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0.253%,0.0772%,0.466%);stroke-opacity:1.0"><line transform="rotate(0, 83.339560664542191, 100.0)" x1="83.339560664542191" x2="83.339560664542191" y1="88.819660112501055" y2="111.18033988749895"></line></g><g class="toyplot-Datum" style="fill:rgb(0.505%,0.154%,0.932%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0.505%,0.154%,0.932%);stroke-opacity:1.0"><line transform="r ...

# %%
toyplot.pdf.render(canvas, 'BlackBodyExtendedMap.pdf')

# %%
colors_long.to_csv('BlackBodyExtendedUChar.csv',
                   index=False,
                   columns=['scalar', 'RGB_r', 'RGB_g', 'RGB_b'])
colors_long.to_csv('BlackBodyExtendedFloat.csv',
                   index=False,
                   columns=['scalar', 'sRGB_r', 'sRGB_g', 'sRGB_b'],
                   header=['scalar', 'RGB_r', 'RGB_g', 'RGB_b'])
